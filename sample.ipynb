# %% [markdown]
# [Multivariate quantiles and long horizon forecasting with N-HiTS](https://pytorch-forecasting.readthedocs.io/en/stable/tutorials/nhits.html)
# ----

# %%
# !pip install -r ./requirements.txt
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting git+https://github.com/KelvinKan/CP-Flow.git@package-specific-version (from -r ./requirements.txt (line 5))
#   Cloning https://github.com/KelvinKan/CP-Flow.git (to revision package-specific-version) to /private/var/folders/zb/tts3v_1n6_q7k08zvlx60d5m0000gn/T/pip-req-build-milm8yd8
#   Running command git clone --filter=blob:none --quiet https://github.com/KelvinKan/CP-Flow.git /private/var/folders/zb/tts3v_1n6_q7k08zvlx60d5m0000gn/T/pip-req-build-milm8yd8
#   Running command git checkout -b package-specific-version --track origin/package-specific-version
#   Switched to a new branch 'package-specific-version'
#   Branch 'package-specific-version' set up to track remote branch 'package-specific-version' from 'origin'.
#   Resolved https://github.com/KelvinKan/CP-Flow.git to commit 02eb8f7243cafb8cf655dfd05c0ee32ccdd32248
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: torchvision in /opt/homebrew/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: pytorch-lightning in /opt/homebrew/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (1.6.5)
# Requirement already satisfied: pytorch-forecasting>=0.10.2 in /opt/homebrew/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.9/site-packages (from torch->-r ./requirements.txt (line 1)) (4.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/homebrew/lib/python3.9/site-packages (from torchvision->-r ./requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.9/site-packages (from torchvision->-r ./requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.9/site-packages (from torchvision->-r ./requirements.txt (line 2)) (1.23.1)
# Requirement already satisfied: torchmetrics>=0.4.1 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: PyYAML>=5.4 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (6.0)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (21.3)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (0.3.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (2022.5.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (2.9.1)
# Requirement already satisfied: protobuf<=3.20.1 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (3.19.4)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-lightning->-r ./requirements.txt (line 3)) (4.64.0)
# Requirement already satisfied: scikit-learn<1.2,>=0.24 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.9/site-packages (from pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (3.5.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: scipy<2.0,>=1.8 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.8.1)
# Requirement already satisfied: optuna<3.0.0,>=2.3.0 in /opt/homebrew/lib/python3.9/site-packages (from pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (2.10.1)
# Requirement already satisfied: statsmodels in /opt/homebrew/lib/python3.9/site-packages (from pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: backports.functools-lru-cache==1.6.1 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: cycler==0.10.0 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: future==0.17.1 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (0.17.1)
# Requirement already satisfied: kiwisolver==1.1.0 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (2.4.7)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: pytz==2020.1 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (2020.1)
# Requirement already satisfied: seaborn==0.9.1 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: six==1.15.0 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: subprocess32==3.5.3 in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (3.5.3)
# Requirement already satisfied: h5py in /opt/homebrew/lib/python3.9/site-packages (from cpflows==0.1.0->-r ./requirements.txt (line 5)) (3.7.0)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.9/site-packages (from kiwisolver==1.1.0->cpflows==0.1.0->-r ./requirements.txt (line 5)) (60.10.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.9/site-packages (from matplotlib->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (4.34.4)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/homebrew/lib/python3.9/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.4.39)
# Requirement already satisfied: alembic in /opt/homebrew/lib/python3.9/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.8.1)
# Requirement already satisfied: cliff in /opt/homebrew/lib/python3.9/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (3.10.1)
# Requirement already satisfied: colorlog in /opt/homebrew/lib/python3.9/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (6.6.0)
# Requirement already satisfied: cmaes>=0.8.2 in /opt/homebrew/lib/python3.9/site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (0.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn<1.2,>=0.24->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/homebrew/lib/python3.9/site-packages (from scikit-learn<1.2,>=0.24->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.44.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /opt/homebrew/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (0.37.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from requests->torchvision->-r ./requirements.txt (line 2)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.9/site-packages (from requests->torchvision->-r ./requirements.txt (line 2)) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.9/site-packages (from requests->torchvision->-r ./requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.9/site-packages (from requests->torchvision->-r ./requirements.txt (line 2)) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in /opt/homebrew/lib/python3.9/site-packages (from statsmodels->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (0.5.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/homebrew/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/homebrew/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (4.12.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->-r ./requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: Mako in /opt/homebrew/lib/python3.9/site-packages (from alembic->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (5.9.0)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/homebrew/lib/python3.9/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (2.4.2)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/homebrew/lib/python3.9/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: autopage>=0.4.0 in /opt/homebrew/lib/python3.9/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/homebrew/lib/python3.9/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (3.3.0)
# Requirement already satisfied: pyperclip>=1.6 in /opt/homebrew/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/homebrew/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->-r ./requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/homebrew/lib/python3.9/site-packages (from Mako->alembic->optuna<3.0.0,>=2.3.0->pytorch-forecasting>=0.10.2->-r ./requirements.txt (line 4)) (2.0.1)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
import os
import warnings

warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
import torch

from pytorch_forecasting import Baseline, NHiTS, TimeSeriesDataSet
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_forecasting.data.examples import generate_ar_data
from pytorch_forecasting.metrics import SMAPE, MQF2DistributionLoss, QuantileLoss

# %%
data = generate_ar_data(seasonality=10.0, timesteps=400, n_series=100, seed=42)
data["static"] = 2
data["date"] = pd.Timestamp("2020-01-01") + pd.to_timedelta(data.time_idx, "D")
data.head()
# Out:
#    series  time_idx     value  static       date
# 0       0         0 -0.000000       2 2020-01-01
# 1       0         1 -0.046501       2 2020-01-02
# 2       0         2 -0.097796       2 2020-01-03
# 3       0         3 -0.144397       2 2020-01-04
# 4       0         4 -0.177954       2 2020-01-05

# %%
# create dataset and dataloaders
max_encoder_length = 60
max_prediction_length = 20

training_cutoff = data["time_idx"].max() - max_prediction_length

context_length = max_encoder_length
prediction_length = max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="value",
    categorical_encoders={"series": NaNLabelEncoder().fit(data.series)},
    group_ids=["series"],
    # only unknown variable is "value" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["value"],
    max_encoder_length=context_length,
    max_prediction_length=prediction_length,
)

validation = TimeSeriesDataSet.from_dataset(training, data, min_prediction_idx=training_cutoff + 1)
batch_size = 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=0)

# %%
data.loc[data['series']==0]['value'].iloc[-max_encoder_length+training_cutoff:training_cutoff].plot();

# %%
# calculate baseline absolute error
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
baseline_predictions = Baseline().predict(val_dataloader)
SMAPE()(baseline_predictions, actuals)
# Out:
# tensor(0.5462)

# %%
pl.seed_everything(42)
trainer = pl.Trainer(gpus=torch.cuda.device_count(), gradient_clip_val=1.0)
net = NHiTS.from_dataset(
    training,
    learning_rate=3e-2,
    weight_decay=1e-2,
    loss=MQF2DistributionLoss(prediction_length=max_prediction_length),
    backcast_loss_ratio=0.0,
    hidden_size=64,
)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# find optimal learning rate
res = trainer.tuner.lr_find(net, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader, min_lr=1e-5)
print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
net.hparams.learning_rate = res.suggestion()
# Out:
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# Restoring states from the checkpoint path at /Users/jimako/ghq/github.com/tk42/nhits-trial/.lr_find_c9054215-dd7c-4b16-823c-227295b2b656.ckpt
# suggested learning rate: 0.17782794100389224

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
trainer = pl.Trainer(
    max_epochs=5,
    gpus=0,
    weights_summary="top",
    gradient_clip_val=1.0,
    callbacks=[early_stop_callback],
    limit_train_batches=30,
    enable_checkpointing=True,
)


net = NHiTS.from_dataset(
    training,
    learning_rate=0.09,
    log_interval=10,
    log_val_interval=1,
    weight_decay=1e-2,
    backcast_loss_ratio=0.0,
    hidden_size=64,
    loss=MQF2DistributionLoss(prediction_length=max_prediction_length),
)

trainer.fit(
    net,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type                 | Params
# ---------------------------------------------------------
# 0 | loss            | MQF2DistributionLoss | 5.1 K
# 1 | logging_metrics | ModuleList           | 0
# 2 | embeddings      | MultiEmbedding       | 0
# 3 | model           | NHiTS                | 35.7 K
# ---------------------------------------------------------
# 40.8 K    Trainable params
# 0         Non-trainable params
# 40.8 K    Total params
# 0.163     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_model = NHiTS.load_from_checkpoint(best_model_path)

# %%
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_model.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(0.2021)

# %%
raw_predictions, x = best_model.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True);

# %%
for idx in range(2):  # plot 10 examples
    best_model.plot_interpretation(x, raw_predictions, idx=idx);

# %%
# sample 500 paths
samples = best_model.loss.sample(raw_predictions["prediction"][[0]], n_samples=500)[0]

# plot prediction
fig = best_model.plot_prediction(x, raw_predictions, idx=0, add_loss_to_title=True)
ax = fig.get_axes()[0]
# plot first two sampled paths
ax.plot(samples[:, 0], color="g", label="Sample 1")
ax.plot(samples[:, 1], color="r", label="Sample 2")
fig.legend();

# %%
print(f"Var(all samples) = {samples.var():.4f}")
print(f"Mean(Var(sample)) = {samples.var(0).mean():.4f}")
# Out:
# Var(all samples) = 0.0856
# Mean(Var(sample)) = 0.0595

# %%
plt.hist(samples.sum(0).numpy(), bins=30)
plt.xlabel("Sum of predictions")
plt.ylabel("Frequency");
